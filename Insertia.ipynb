# %%
k="""
Pikeman Pikeman 	Town portrait Castle small.gif 	1 	4 	5 	1 	3 	10 	4 	14 	80 	60 Gold 	  	Immune to jousting
Halberdier Halberdier 	Town portrait Castle small.gif 	1+ 	6 	5 	2 	3 	10 	5 	14 	115 	75 Gold 	  	Immune to jousting
Archer Archer 	Town portrait Castle small.gif 	2 	6 	3 	2 	3 	10 	4 	9 	126 	100 Gold 	  	Ranged (12 shots)
Marksman Marksman 	Town portrait Castle small.gif 	2+ 	6 	3 	2 	3 	10 	6 	9 	184 	150 Gold 	  	Ranged (24 shots), Double attack
Griffin Griffin 	Town portrait Castle small.gif 	3 	8 	8 	3 	6 	25 	6 	7 	351 	200 Gold 	  	Flying, Two retaliations
Royal Griffin Royal Griffin 	Town portrait Castle small.gif 	3+ 	9 	9 	3 	6 	25 	9 	7 	448 	240 Gold 	  	Flying, Unlimited retaliations
Swordsman Swordsman 	Town portrait Castle small.gif 	4 	10 	12 	6 	9 	35 	5 	4 	445 	300 Gold 	  	
Crusader Crusader 	Town portrait Castle small.gif 	4+ 	12 	12 	7 	10 	35 	6 	4 	558 	400 Gold 	  	Double attack
Monk Monk 	Town portrait Castle small.gif 	5 	12 	7 	10 	12 	30 	5 	3 	485 	400 Gold 	  	Ranged (12 shots)
Zealot Zealot 	Town portrait Castle small.gif 	5+ 	12 	10 	10 	12 	30 	7 	3 	750 	450 Gold 	  	Ranged (24 shots), No melee penalty
Cavalier Cavalier 	Town portrait Castle small.gif 	6 	15 	15 	15 	25 	100 	7 	2 	1946 	1000 Gold 	  	Jousting
Champion Champion 	Town portrait Castle small.gif 	6+ 	16 	16 	20 	25 	100 	9 	2 	2100 	1200 Gold 	  	Jousting
Angel Angel 	Town portrait Castle small.gif 	7 	20 	20 	50 	50 	200 	12 	1 	5019 	3000 Gold 	, 1 Gem  	Flying, Hates Devils, Morale +1
Archangel Archangel 	Town portrait Castle small.gif 	7+ 	30 	30 	50 	50 	250 	18 	1 	8776 	5000 Gold 	, 3 Gem  	Flying, Hates Devils, Resurrection, Morale +1
Centaur Centaur 	Town portrait Rampart small.gif 	1 	5 	3 	2 	3 	8 	6 	14 	100 	70 Gold 	  	
Centaur Captain Centaur Captain 	Town portrait Rampart small.gif 	1+ 	6 	3 	2 	3 	10 	8 	14 	138 	90 Gold 	  	
Dwarf Dwarf 	Town portrait Rampart small.gif 	2 	6 	7 	2 	4 	20 	3 	8 	138 	120 Gold 	  	Resistance +20%
Battle Dwarf Battle Dwarf 	Town portrait Rampart small.gif 	2+ 	7 	7 	2 	4 	20 	5 	8 	209 	150 Gold 	  	Resistance +40%
Wood Elf Wood Elf 	Town portrait Rampart small.gif 	3 	9 	5 	3 	5 	15 	6 	7 	234 	200 Gold 	  	Ranged (24 shots)
Grand Elf Grand Elf 	Town portrait Rampart small.gif 	3+ 	9 	5 	3 	5 	15 	7 	7 	331 	225 Gold 	  	Ranged (24 shots), Double attack
Pegasus Pegasus 	Town portrait Rampart small.gif 	4 	9 	8 	5 	9 	30 	8 	5 	518 	250 Gold 	  	Flying, Magic damper
Silver Pegasus Silver Pegasus 	Town portrait Rampart small.gif 	4+ 	9 	10 	5 	9 	30 	12 	5 	532 	275 Gold 	  	Flying, Magic damper
Dendroid Guard Dendroid Guard 	Town portrait Rampart small.gif 	5 	9 	12 	10 	14 	55 	3 	3 	517 	350 Gold 	  	Binding
Dendroid Soldier Dendroid Soldier 	Town portrait Rampart small.gif 	5+ 	9 	12 	10 	14 	65 	4 	3 	803 	425 Gold 	  	Binding
Unicorn Unicorn 	Town portrait Rampart small.gif 	6 	15 	14 	18 	22 	90 	7 	2 	1806 	850 Gold 	  	Blind, Aura of Resistance +20%
War Unicorn War Unicorn 	Town portrait Rampart small.gif 	6+ 	15 	14 	18 	22 	110 	9 	2 	2030 	950 Gold 	  	Blind, Aura of Resistance +20%
Green Dragon Green Dragon 	Town portrait Rampart small.gif 	7 	18 	18 	40 	50 	180 	10 	1 	4872 	2400 Gold 	, 1 Crystal  	Flying, Breath attack, Resist lvl 1–3 spells
Gold Dragon Gold Dragon 	Town portrait Rampart small.gif 	7+ 	27 	27 	40 	50 	250 	16 	1 	8613 	4000 Gold 	, 2 Crystal  	Flying, Breath attack, Resist lvl 1–4 spells
Gremlin Gremlin 	Town portrait Tower small.gif 	1 	3 	3 	1 	2 	4 	4 	16 	44 	30 Gold 	  	
Master Gremlin Master Gremlin 	Town portrait Tower small.gif 	1+ 	4 	4 	1 	2 	4 	5 	16 	66 	40 Gold 	  	Ranged (8 shots)
Stone Gargoyle Stone Gargoyle 	Town portrait Tower small.gif 	2 	6 	6 	2 	3 	16 	6 	9 	165 	130 Gold 	  	Flying, Unliving
Obsidian Gargoyle Obsidian Gargoyle 	Town portrait Tower small.gif 	2+ 	7 	7 	2 	3 	16 	9 	9 	201 	160 Gold 	  	Flying, Unliving
Stone Golem Stone Golem 	Town portrait Tower small.gif 	3 	7 	10 	4 	5 	30 	3 	6 	250 	150 Gold 	  	Unliving, Spell Damage Resistance +50%
Iron Golem Iron Golem 	Town portrait Tower small.gif 	3+ 	9 	10 	4 	5 	35 	5 	6 	412 	200 Gold 	  	Unliving, Spell Damage Resistance +75%
Mage Mage 	Town portrait Tower small.gif 	4 	11 	8 	7 	9 	25 	5 	4 	570 	350 Gold 	  	Ranged (24 shots), No melee penalty, Spells cost -2 sp
Arch Mage Arch Mage 	Town portrait Tower small.gif 	4+ 	12 	9 	7 	9 	30 	7 	4 	680 	450 Gold 	  	Ranged (24 shots), No melee penalty, No Obstacle penalty, Spells cost -2 sp
Genie Genie 	Town portrait Tower small.gif 	5 	12 	12 	13 	16 	40 	7 	3 	884 	550 Gold 	  	Flying, Hates Efreets
Master Genie Master Genie 	Town portrait Tower small.gif 	5+ 	12 	12 	13 	16 	40 	11 	3 	942 	600 Gold 	  	Flying, Spellcaster, Hates Efreets
Naga Naga 	Town portrait Tower small.gif 	6 	16 	13 	20 	20 	110 	5 	2 	2016 	1100 Gold 	  	No enemy retaliation
Water Elemental Water Elemental 	Town portrait Conflux small.gif 	3 	8 	10 	3 	7 	30 	5 	6 	315 	300 Gold 	  	Elemental, Fire vulnerability, Ice immunity
Ice Elemental Ice Elemental 	Town portrait Conflux small.gif 	3+ 	8 	10 	3 	7 	30 	6 	6 	380 	375 Gold 	  	Elemental, Ranged (24 shots), Fire vulnerability, Ice immunity, Spellcaster
Fire Elemental Fire Elemental 	Town portrait Conflux small.gif 	4 	10 	8 	4 	6 	35 	6 	5 	345 	350 Gold 	  	Elemental, Ice vulnerability, Fire immunity
Energy Elemental Energy Elemental 	Town portrait Conflux small.gif 	4+ 	12 	8 	4 	6 	35 	8 	5 	470 	400 Gold 	  	Elemental, Flying, Ice vulnerability, Fire immunity, Spellcaster
Earth Elemental Earth Elemental 	Town portrait Conflux small.gif 	5 	10 	10 	4 	8 	40 	4 	4 	330 	400 Gold 	  	Elemental, Meteor Shower vulnerability, Lightning immunity
Magma Elemental Magma Elemental 	Town portrait Conflux small.gif 	5+ 	11 	11 	6 	10 	40 	6 	4 	490 	500 Gold 	  	Elemental, Meteor Shower vulnerability, Lightning immunity, Spellcaster
Psychic Elemental Psychic Elemental 	Town portrait Conflux small.gif 	6 	15 	13 	10 	20 	75 	7 	2 	1669 	750 Gold 	  	Elemental, No enemy retaliation, Attack adjacent hexes
Magic Elemental Magic Elemental 	Town portrait Conflux small.gif 	6+ 	15 	13 	15 	25 	80 	9 	2 	2012 	800 Gold 	  	Elemental, No enemy retaliation, Attack adjacent hexes, Spell immunity
Firebird Firebird 	Town portrait Conflux small.gif 	7 	18 	18 	30 	40 	150 	15 	2 	4547 	1500 Gold 	  	Flying, Breath attack, Immune to fire spells
Phoenix Phoenix 	Town portrait Conflux small.gif 	7+ 	21 	18 	30 	40 	200 	21 	2 	6721 	2000 Gold 	, 1 Mercury  	Flying, Breath attack, Immune to fire spells, Rebirth
Peasant Peasant 	Town portrait Neutral small.gif 	1 	1 	1 	1 	1 	1 	3 	25 	15 	10 Gold 	  	
Halfling Halfling 	Town portrait Neutral small.gif 	1 	4 	2 	1 	3 	4 	5 	15 	75 	40 Gold 	  	Ranged (24 shots), Luck +1
Boar Boar 	Town portrait Neutral small.gif 	2 	6 	5 	2 	3 	15 	6 	8 	145 	150 Gold 	  	
Rogue Rogue 	Town portrait Neutral small.gif 	2 	8 	3 	2 	4 	10 	6 	8 	135 	100 Gold 	  	Spying
Mummy Mummy 	Town portrait Neutral small.gif 	3 	7 	7 	3 	5 	30 	5 	7 	270 	300 Gold 	  	Undead, Curse
Nomad Nomad 	Town portrait Neutral small.gif 	3 	9 	8 	2 	6 	30 	7 	7 	345 	200 Gold 	  	Sandwalker
Sharpshooter Sharpshooter 	Town portrait Neutral small.gif 	4 	12 	10 	8 	10 	15 	9 	4 	585 	400 Gold 	  	Ranged (32 shots), No Range and Obstacle penalty
Troll Troll 	Town portrait Neutral small.gif 	5 	14 	7 	10 	15 	40 	7 	3 	1024 	500 Gold 	  	Regeneration
Gold Golem Gold Golem 	Town portrait Neutral small.gif 	5 	11 	12 	8 	10 	50 	5 	3 	600 	500 Gold 	  	Unliving, Spell Damage Resistance +85%
Diamond Golem Diamond Golem 	Town portrait Neutral small.gif 	6 	13 	12 	10 	14 	60 	5 	2 	775 	750 Gold 	  	Unliving, Spell Damage Resistance +95%
Enchanter Enchanter 	Town portrait Neutral small.gif 	6 	17 	12 	14 	14 	30 	9 	2 	1210 	750 Gold 	  	Ranged (32 shots), No Melee, Spellcaster
Faerie Dragon Faerie Dragon 	Town portrait Neutral small.gif 	7 	20 	20 	20 	30 	500 	15 	1 	19580 	10000 Gold 	, 8 Gem  	Flying, Dragon, Spellcaster, Magic Mirror
Rust Dragon Rust Dragon 	Town portrait Neutral small.gif 	7 	30 	30 	50 	50 	750 	17 	1 	26433 	15000 Gold 	,14 Sulfur  	Flying, Dragon, Acid breath
Crystal Dragon Crystal Dragon 	Town portrait Neutral small.gif 	7 	40 	40 	60 	75 	800 	16 	1 	39338 	20000 Gold 	,10 Crystal  	Dragon, Crystal generation, Resistance +20%, Unliving
Azure Dragon Azure Dragon 	Town portrait Neutral small.gif 	7 	50 	50 	70 	80 	1000 	19 	1 	78845 	30000 Gold 	,20 Mercury  	Flying, Dragon, Breath, Fear, Resist lvl 1–3 spells, Resist Fear
"""

# %%
wx=[
"""
 Guardhouse 	
  	  	 Ore
10 	  	  	  	 Gold
500
	• Fort 	Pikeman Pikeman 	14
 Upg. Guardhouse 	
  	  	 Ore
5 	  	  	  	 Gold
1000
	• Guardhouse
	Halberdier Halberdier 	14
 Archers' Tower 	
 Wood
5 	  	 Ore
5 	  	  	  	 Gold
1000
	• Guardhouse 	Archer Archer 	9
 Upg. Archers' Tower 	
 Wood
5 	  	 Ore
5 	  	  	  	 Gold
1000
	• Archers' Tower
	Marksman Marksman 	9
 Griffin Tower 	
  	  	 Ore
5 	  	  	  	 Gold
1000
	• Barracks 	Griffin Griffin 	7
 Upg. Griffin Tower 	
  	  	 Ore
5 	  	  	  	 Gold
1000
	• Griffin Tower
	Royal Griffin Royal Griffin 	7
 Barracks 	
  	  	 Ore
5 	  	  	  	 Gold
2000
	• Guardhouse
• Blacksmith 	Swordsman Swordsman 	4
 Upg. Barracks 	
  	  	 Ore
5 	  	 Crystal
5 	  	 Gold
2000
	• Barracks
	Crusader Crusader 	4
 Monastery 	
 Wood
5 	 Mercury
2 	 Ore
5 	 Sulfur
2 	 Crystal
2 	 Gem
2 	 Gold
3000
	• Mage guild 
• Barracks 	Monk Monk 	3
 Upg. Monastery 	
 Wood
2 	 Mercury
2 	 Ore
2 	 Sulfur
2 	 Crystal
2 	 Gem
2 	 Gold
1000
	• Monastery
	Zealot Zealot 	3
 Training Grounds 	
 Wood
20 	  	  	  	  	  	 Gold
5000
	• Stables
• Barracks 	Cavalier Cavalier 	2
 Upg. Training Grounds 	
 Wood
10 	  	  	  	  	  	 Gold
3000
	• Training Grounds
	Champion Champion 	2
 Portal of Glory 	
  	 Mercury
10 	  	 Sulfur
10 	 Crystal
10 	 Gem
10 	 Gold
20000
	• Monastery 	Angel Angel 	1
 Upg. Portal of Glory 	
  	 Mercury
10 	  	 Sulfur
10 	 Crystal
10 	 Gem
10 	 Gold
20000
	• Portal of Glory
	Archangel Archangel 	1 
""", 


    
"""
 Centaur Stables 	
 Wood
5 	  	  	  	  	  	 Gold
500
	• Fort 	Centaur Centaur 	14
 Upg. Centaur Stables 	
 Wood
5 	  	  	  	  	  	 Gold
1000
	•
 Upg. Pyre 	
 Wood
20 	 Mercury
10 	 Ore
10 	  	  	  	 Gold
15000
	• Pyre
	Phoenix Phoenix 	2 
"""
]

# %%
wy=[
"""
Mage Guild Level 1 	
 Wood
5 	  	 Ore
5 	  	  	  	 Gold
2000
	• Village Hall 	Five level 1 spells become available for heroes to learn. Heroes are able to purchase a spell book for 500 Gold.
Mage Guild Level 2 	
 Wood
5 	 Mercury
4 	 Ore
5 	 Sulfur
4 	 Crystal
4 	 Gem
4 	 Gold
1000
	• Mage Guild Level 1 	Four level 2 spells become available for heroes to learn.
Mage Guild Level 3 	
 Wood
5 	 Mercury
6 	 Ore
5 	 Sulfur
6 	 Crystal
6 	 Gem
6 	 Gold
1000
	• Mage Guild Level 2 	Three level 3 spells become available for heroes to learn.
Mage Guild Level 4 	
 Wood
5 	 Mercury
8 	 Ore
5 	 Sulfur
8 	 Crystal
8 	 Gem
8 	 Gold
1000
	• Mage Guild Level 3 	Two level 4 spells become available for heroes to learn.
Mage Guild Level 5 	
 Wood
5 	 Mercury
10 	 Ore
5 	 Sulfur
10 	 Crystal
10 	 Gem
10 	 Gold
1000
	• Mage Guild Level 4 	One level 5 spell becomes available for heroes to learn. 

""",
    
"""
Buildings Fort.gif
Fort 	
  	 Wood
 20 	  	 Ore
 20 	  	 Gold
 5000 	 
	• Village Hall 	Adds walls to a town
Buildings Citadel.gif
Citadel 	
  	  	  	 Ore
 5 	  	 Gold
 2500 	 
	• Fort 	Adds moat and primary arrow tower to a town. Increases production of creature dwellings by 50%.
Buildings Castle.gif
Castle 	
  	 Wood
 10 	  	 Ore
 10 	  	 Gold
 5000 	 
	• Citadel 	Adds two secondary arrow towers, standard walls are strengthened to fortified walls. Increases production of creature dwellings by 100%. 

""",
    
"""
Buildings Town Hall.gif
Town Hall 	
  	  	  	 Gold
2500 	  	  	 
	• Village Hall
• Tavern 	Provides 1000 Gold per day.
Buildings City Hall.gif
City Hall 	
  	  	  	 Gold
5000 	  	  	 
	• Town Hall
• Blacksmith
• Mage Guild Level 1
• Marketplace 	Provides 2000 Gold per day.
Buildings Capitol.gif
Capitol 	
  	  	  	 Gold
10000 	  	  	 
	• City Hall
• Castle 	Provides 4000 Gold per day. 
"""
]

# %%
cst=['Castle', 'Rampart', 'Tower', 'Inferno', 'Necropolis', 'Dungeon', 'Stronghold', 'Fortress', 'Conflux']
for x in cst:
    print(f"insert into castles values('{x}');")
# Out:
# insert into castles values('Castle');
# insert into castles values('Rampart');
# insert into castles values('Tower');
# insert into castles values('Inferno');
# insert into castles values('Necropolis');
# insert into castles values('Dungeon');
# insert into castles values('Stronghold');
# insert into castles values('Fortress');
# insert into castles values('Conflux');

# %%
import re


resdict=[]

x=(re.split('\n', k))[1:]
for l in x:
    st=re.split('\t', l)
    
    try:
        v=st[1][14:][:re.search(' ', st[1][14:]).span()[0]]
        if (v=='Neutral'):
            v='null'
        else:
            v="'"+v+"'"
        
        rd={'gold':int(re.split(' ', st[11])[0])}
        try:
            x=st[12][re.search(',', st[12]).span()[1]:]
            y=x[3:].lower()
            y=re.sub(' ', '', y)
            if (x[0]==' '):
                z=int(x[1])
            else:
                z=int(x[0:2])
            rd[y]=z
        except:
            pass
        if (rd not in resdict):
            c=len(resdict)+1
            resdict.append(rd)
        else:
            c=resdict.index(rd)+1
            
        print(f"insert into unit values('{st[0][:len(st[0])//2-1]}', {v}, {c}, {st[3]}, {st[4]}, {st[7]}, {st[8]}, {st[5]}, {st[6]});")
            
    except:
        pass
# Out:
# insert into unit values('Pikeman', 'Castle', 1, 4 , 5 , 10 , 4 , 1 , 3 );
# insert into unit values('Halberdier', 'Castle', 2, 6 , 5 , 10 , 5 , 2 , 3 );
# insert into unit values('Archer', 'Castle', 3, 6 , 3 , 10 , 4 , 2 , 3 );
# insert into unit values('Marksman', 'Castle', 4, 6 , 3 , 10 , 6 , 2 , 3 );
# insert into unit values('Griffin', 'Castle', 5, 8 , 8 , 25 , 6 , 3 , 6 );
# insert into unit values('Royal Griffin', 'Castle', 6, 9 , 9 , 25 , 9 , 3 , 6 );
# insert into unit values('Swordsman', 'Castle', 7, 10 , 12 , 35 , 5 , 6 , 9 );
# insert into unit values('Crusader', 'Castle', 8, 12 , 12 , 35 , 6 , 7 , 10 );
# insert into unit values('Monk', 'Castle', 8, 12 , 7 , 30 , 5 , 10 , 12 );
# insert into unit values('Zealot', 'Castle', 9, 12 , 10 , 30 , 7 , 10 , 12 );
# insert into unit values('Cavalier', 'Castle', 10, 15 , 15 , 100 , 7 , 15 , 25 );
# insert into unit values('Champion', 'Castle', 11, 16 , 16 , 100 , 9 , 20 , 25 );
# ...

# %%
for j, w in enumerate(wx):
    s=re.split('\t', w)
    for i in range(0, len(s), 10):
        rd={}
        try:
            vv=re.split('\n ', s[i:10+i][0])[1]
            s[1+i]=s[1+i][1:]
            for gg in s[1+i:8+i]:
                try:
                    zv=re.split('\n', gg)
                    y=zv[0][1:].lower()
                    z=int(zv[1][0:])
                    rd[y]=z
                except:
                    pass
            if (rd not in resdict):
                c=len(resdict)+1
                resdict.append(rd)
            else:
                c=resdict.index(rd)+1
            print(f"insert into castle_building values('{vv[:-1]}', '{cst[j]}', {c});")
        except:
            pass
    print()
# Out:
# insert into castle_building values('Guardhouse', 'Castle', 77);
# insert into castle_building values('Upg. Guardhouse', 'Castle', 78);
# insert into castle_building values('Archers' Tower', 'Castle', 79);
# insert into castle_building values('Upg. Archers' Tower', 'Castle', 79);
# insert into castle_building values('Griffin Tower', 'Castle', 78);
# insert into castle_building values('Upg. Griffin Tower', 'Castle', 78);
# insert into castle_building values('Barracks', 'Castle', 80);
# insert into castle_building values('Upg. Barracks', 'Castle', 81);
# insert into castle_building values('Monastery', 'Castle', 82);
# insert into castle_building values('Upg. Monastery', 'Castle', 83);
# insert into castle_building values('Training Grounds', 'Castle', 84);
# insert into castle_building values('Upg. Training Grounds', 'Castle', 85);
# insert into castle_building values('Portal of Glory', 'Castle', 86);
# insert into castle_building values('Upg. Portal of Glory', 'Castle', 86);
#
# ...

# %%
for w in wy:
    s=re.split('\t', w)
    
    for i in range(0, len(s), 9):
        rd={}
        try:
            vv=re.split('\n', s[i:5+i][0])[1]
            vv=re.split('.gif', vv)[0]
            vv=re.split('Buildings ', vv)
            vv=vv[1] if (len(vv)>1) else vv[0]
            if (len(vv[0])==0):
                continue
                
            if(re.search('Guild', vv)):
                vv=vv[:-1]
                
            s[1+i]=s[1+i][1:]
            for gg in s[1+i:8+i]:
                try:
                    zv=re.split('\n', gg)
                    y=zv[0][1:].lower()
                    z=int(zv[1][0:])
                    rd[y]=z
                except:
                    pass
            if (rd not in resdict):
                c=len(resdict)+1
                resdict.append(rd)
            else:
                c=resdict.index(rd)+1
            
            
            for x in cst:
                print(f"insert into castle_building values('{vv}', '{x}', {c});")
        except:
            pass
    print()
# Out:
# insert into castle_building values('Mage Guild Level 1', 'Castle', 100);
# insert into castle_building values('Mage Guild Level 1', 'Rampart', 100);
# insert into castle_building values('Mage Guild Level 1', 'Tower', 100);
# insert into castle_building values('Mage Guild Level 1', 'Inferno', 100);
# insert into castle_building values('Mage Guild Level 1', 'Necropolis', 100);
# insert into castle_building values('Mage Guild Level 1', 'Dungeon', 100);
# insert into castle_building values('Mage Guild Level 1', 'Stronghold', 100);
# insert into castle_building values('Mage Guild Level 1', 'Fortress', 100);
# insert into castle_building values('Mage Guild Level 1', 'Conflux', 100);
# insert into castle_building values('Mage Guild Level 2', 'Castle', 160);
# insert into castle_building values('Mage Guild Level 2', 'Rampart', 160);
# insert into castle_building values('Mage Guild Level 2', 'Tower', 160);
# insert into castle_building values('Mage Guild Level 2', 'Inferno', 160);
# ...

# %%
lees=['gold', 'wood', 'ore', 'gem', 'sulfur', 'mercury', 'crystal']
for x in resdict:
    mine="insert into resources values("
    for i, y in enumerate(lees):
        try:
            x[y]
            mine=mine+str(x[y])
        except:
            mine=mine+"0"
            
        if (i<len(lees)-1):
            mine=mine+", "
        else:
            mine=mine+");"
    print(mine)
# Out:
# insert into resources values(60, 0, 0, 0, 0, 0, 0);
# insert into resources values(75, 0, 0, 0, 0, 0, 0);
# insert into resources values(100, 0, 0, 0, 0, 0, 0);
# insert into resources values(150, 0, 0, 0, 0, 0, 0);
# insert into resources values(200, 0, 0, 0, 0, 0, 0);
# insert into resources values(240, 0, 0, 0, 0, 0, 0);
# insert into resources values(300, 0, 0, 0, 0, 0, 0);
# insert into resources values(400, 0, 0, 0, 0, 0, 0);
# insert into resources values(450, 0, 0, 0, 0, 0, 0);
# insert into resources values(1000, 0, 0, 0, 0, 0, 0);
# insert into resources values(1200, 0, 0, 0, 0, 0, 0);
# insert into resources values(3000, 0, 0, 1, 0, 0, 0);
# insert into resources values(5000, 0, 0, 3, 0, 0, 0);
# insert into resources values(70, 0, 0, 0, 0, 0, 0);
# insert into resources values(90, 0, 0, 0, 0, 0, 0);
# insert into resources values(120, 0, 0, 0, 0, 0, 0);
# insert into resources values(225, 0, 0, 0, 0, 0, 0);
# insert into resources values(250, 0, 0, 0, 0, 0, 0);
# ...
